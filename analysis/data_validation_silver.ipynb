# %%
import pandas as pd

# %%
#visualizar os dados do tipo yellow
df = pd.read_parquet('s3://talita-costa-pipeline/silver/ny/taxi_rides/yellow/year=2023/month=4/part-00000-4484f4f8-5144-4ab5-a5c5-98eb0652adfb.c000.snappy.parquet')

df.info()
display(df.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130498 entries, 0 to 130497
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   vendor_id         130498 non-null  object
#  1   passenger_count   130498 non-null  int32
#  2   total_amount      130498 non-null  float64
#  3   pickup_datetime   130498 non-null  datetime64[us]
#  4   dropoff_datetime  130498 non-null  datetime64[us]
#  5   type              130498 non-null  object
#  6   key               130498 non-null  object
#  7   year              130498 non-null  category
#  8   month             130498 non-null  category
# dtypes: category(2), datetime64[us](2), float64(1), int32(1), object(3)
# memory usage: 6.7+ MB
#   vendor_id  passenger_count  total_amount     pickup_datetime  \
# 0         2                1         19.80 2023-04-12 19:11:30
# 1         1                1         15.80 2023-04-12 17:26:05
# ...

# %%
#visualizar os dados do tipo green
df = pd.read_parquet('s3://talita-costa-pipeline/silver/ny/taxi_rides/green/year=2023/month=3/part-00000-a1f63b7b-f88f-4f02-9a75-256ec5d9a0e0.c000.snappy.parquet')

df.info()
display(df.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5729 entries, 0 to 5728
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   vendor_id         5729 non-null   object
#  1   passenger_count   5729 non-null   int32
#  2   total_amount      5729 non-null   float64
#  3   pickup_datetime   5729 non-null   datetime64[us]
#  4   dropoff_datetime  5729 non-null   datetime64[us]
#  5   type              5729 non-null   object
#  6   key               5729 non-null   object
#  7   year              5729 non-null   category
#  8   month             5729 non-null   category
# dtypes: category(2), datetime64[us](2), float64(1), int32(1), object(3)
# memory usage: 302.4+ KB
#   vendor_id  passenger_count  total_amount     pickup_datetime  \
# 0         1                1         13.22 2023-03-28 08:19:08
# 1         2                1          8.70 2023-03-20 11:11:38
# ...
